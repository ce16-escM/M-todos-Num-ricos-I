# %% [markdown]
# <a href="https://colab.research.google.com/github/ce16-escM/M-todos-Num-ricos-I/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy

# %%
def f(x):
   return (x-2)**2

# %%
f(2)
# Out:
# 0
